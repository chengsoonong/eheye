# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

# %%
r1 = np.random.normal(400, 30, 1000)
r2 = np.random.normal(20, 60, 300)
r3 = np.random.uniform(20, 320, 500)
rnd = np.append(np.append(r1, r2), r3)

fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(1,1,1)

ax.hist(rnd, bins=100, color='royalblue')

# Major ticks every 20, minor ticks every 5
x_major_ticks = np.arange(-160, 540, 100)
x_minor_ticks = np.arange(-160, 540, 20)
y_major_ticks = np.arange(0, 101, 20)
y_minor_ticks = np.arange(0, 101, 5)

ax.set_xticks(x_major_ticks)
ax.set_xticks(x_minor_ticks, minor=True)
ax.set_yticks(y_major_ticks)
ax.set_yticks(y_minor_ticks, minor=True)

# And a corresponding grid
ax.grid(which='both')

# # Or if you want different settings for the grids:
ax.grid(which='major', alpha=0.7, linestyle='--')
ax.grid(which='minor', alpha=0.5, linestyle=':')

# %%
def get_one_dt(distro, datasize):
#     return np.ones(size)
    if distro == 'gau_1':
        return np.random.normal(2, 18, datasize)
    elif distro == 'gau_2':
        return np.random.normal(0, 0.001, datasize)
    
def get_q_true(distro, tau_lst):
    if tau_lst == tau_vals:
        if distro=='gau_1':
            return np.asarray([-21.06792817980280840537, 
                              -7.43920922874473411269,
                              2,
                              25.06792817980280840537,
                              43.87426173273513981594])
        elif distro=='gau_2':
            return np.asarray([-0.001281551565544600466965,
                              -5.244005127080407840383E-4,
                              0,
                              0.001281551565544600466965,
                              0.002326347874040841100886])
        elif distro=='mix':
            # sampled from 100000000 datapoints
            return np.asarray([-80.28496182,
                               -29.02324254,
                               -0.36011575,
                               36.69268923,
                               120.7676231])
        elif distro=='exp':
            return np.asarray([0.1053605156578263012275,
                              0.3566749439387323789126,
                              0.6931471805599453094172,
                              2.302585092994045684018,
                              4.605170185988091368036])*6.5 - 20
    raise Exception('tau_lst should be tau_vals')
    
    
def get_procs(dataset, step_size, tau_lst):
    if len(dataset.shape)!= 1: 
        raise Exception('Dataset for get_procs() of wrong shape:' + str(dataset.shape)+ ', should be 1d array')
        
    procs = np.zeros((len(tau_lst), dataset.shape[0]))
    for idx, tau in enumerate(tau_lst):
        q = 0
        q_sgd_proc = procs[idx]
        # change stepsize
        if step_size != 'frugal':
            for k, x in enumerate(dataset):
#                 if idx==1: print (k, ':', q)
                alpha = set_stepsize(k+1, step_size)
                if x > q:
                    q = q + alpha*tau
                else:
                    q = q - alpha*(1-tau)
                q_sgd_proc[k] = q
        
        # frugal
        else:
            rdn_lst = np.random.uniform(0,1, dataset.shape[0])
            for k, x in enumerate(dataset):
                rdn = rdn_lst[k]
                if x > q and rdn > 1-tau:
                    q += 2
                elif x < q and rdn > tau:
                    q -= 2
                q_sgd_proc[k] = q
    return procs

# %%
tau_vals = [0.1, 0.3, 0.5, 0.9, 0.99]
# sample_size = 
sample = get_one_dt('gau_1', 2000)
q_true = get_q_true('gau_1', tau_vals)
procs = get_procs(sample, 'frugal', tau_vals).T
print (procs.shape)
# Out:
# (2000, 5)

# %%
fig, (ax1, ax2) = plt.subplots(1,2, sharey=True, figsize=(15,4), gridspec_kw={'width_ratios': [5, 1]})

ax1.plot(procs[:, 4], color='dodgerblue')
# ax1.hlines(y = q_true[1],xmin = 0, xmax = 100, colors = 'royalblue', linestyles='dotted')
ax1.axhline(q_true[4], color='darkviolet', ls = ':')
ax1.plot(sample, 'o', label = 'data point', markersize=1, color = 'lightseagreen')

ax2.hist(sample, bins=50, orientation="horizontal", color='lightseagreen');
# ax2.hlines(y = q_true[1], xmin = 0, xmax = 1000, colors = ['royalblue']*5, linestyles='dotted')
ax2.axhline(q_true[4], color='darkviolet', ls = ':')
ax2.plot()
plt.show()

fig.savefig('foo.png')

# %%
fig, ax = plt.subplots()
fig.set_size_inches(8,5)
ax.hist(sample, bins=50, color='dodgerblue');
# ax.axvline(q_true[0], color='grey', ls = ':', linewidth=2)
# ax.axvline(q_true[1], color='grey', ls = ':')
ax.axvline(q_true[2], color='yellow', ls = ':', linewidth=3)
ax.axvline(q_true[3], color='grey', ls = ':', linewidth=2.5)
ax.axvline(q_true[4], color='darkviolet', ls = ':', linewidth=2)
plt.show()
fig.savefig('foo1.png')

# %%
import scipy.stats as stats
import math


# plt.figure(figsize=(20,10))
fig, ax = plt.subplots()
mu = 2
variance = 18*18
sigma = math.sqrt(variance)
x = np.linspace(mu - 3*sigma, mu + 3*sigma, 100)
# plt.legend(x, "gau_1")
# plt.show()

mu = 0
variance = (0.001)*(0.001)
sigma = math.sqrt(variance)
y = np.linspace(mu - 3*sigma, mu + 3*sigma, 100)
plt.plot(y, stats.norm.pdf(y, mu, sigma))
plt.plot(x, stats.norm.pdf(x, mu, sigma))

plt.show()
fig.savefig("two_gaussians")

# %%
# N_data = 100
# p2_rdn = np.random.normal(0.0, 1.0, N_data)

# quant = [sorted(p2_rdn)[i] for i in ([9,39,59])]
# print (quant)

# p2_act_pos = np.repeat(sorted(p2_rdn),2)
# p2_height = np.repeat(np.arange(N_data+1),2)[1:-1]
# Out:
# [-1.188797709325664, -0.04895832718547234, 0.35240930449837204]

# %%
fig, ax = plt.subplots(1,1)
fig.set_size_inches(9,8)
ax.plot(p2_act_pos, (p2_height/N_data))
ax.set_xlabel('quantile value', fontsize = 16)
plt.xticks(quant, ['$q_{i-1}$', '$q_{i}$', '$q_{i+1}$'], fontsize = 15)

ax.set_ylabel("tau value", fontsize = 16)
ax.tick_params('y')
plt.yticks([0.1, 0.40, 0.60], [r'$\tau_{i-1}$', r'$\tau_{i}$', r'$\tau_{i+1}$'], fontsize = 15)

ax2 = ax.twinx()
ax2.plot(p2_act_pos, p2_height)
plt.yticks([10, 40, 60], ['$m_{i-1}$', '$m_{i}$', '$m_{i+1}$'], fontsize = 15)
ax2.set_ylabel("marker position", fontsize = 16)

plt.tight_layout()
fig.savefig("p2_relationship")

# %%
fig, ax = plt.subplots(1,1)
fig.set_size_inches(7,6)

ax.scatter([10,40,60], [sorted(p2_rdn)[i] for i in [9,39,59]], color = 'white')

ax.plot((p2_height), p2_act_pos, color = 'white')
ax.set_ylabel('quantile value', fontsize = 16)
plt.yticks(quant, ['$q_{i-1}$', '$q_{i}$', '$q_{i+1}$'], fontsize = 15)

ax.set_xlabel("marker position", fontsize = 16)
ax.tick_params('y')
plt.xticks([10, 40, 60], ['$m_{i-1}$', '$m_{i}$', '$m_{i+1}$'], fontsize = 15)

plt.tight_layout()
fig.savefig("p2_parabola")

# %%
# fig.savefig('p2_parabola')

# %%
import numpy as np
from scipy.stats import binom
from matplotlib import pyplot as plt
# %matplotlib inline
#----------------------------------------------------------------------
# This function adjusts matplotlib settings for a uniform feel in the textbook.
# Note that with usetex=True, fonts are rendered with LaTeX.  This may
# result in an error if LaTeX is not installed on your system.  In that case,
# you can set usetex to False.
# if "setup_text_plots" not in globals():
#     from astroML.plotting import setup_text_plots
# setup_text_plots(fontsize=8, usetex=True)

#------------------------------------------------------------
# Define the distribution parameters to be plotted
n_values = [200, 200, 200]
b_values = [0.1, 0.5, 0.99]
linestyles = ['-', '--', ':']
x = np.arange(-1, 200)

#------------------------------------------------------------
# plot the distributions
fig, ax = plt.subplots(figsize=(8, 3))
plt.gcf().subplots_adjust(bottom=0.15)

for (n, b, ls) in zip(n_values, b_values, linestyles):
    # create a binomial distribution
    dist = binom(n, b)

    plt.plot(x, dist.pmf(x), color='black', linestyle='steps-mid' + ls,
             label=r'$b=%.2f,\ n=%i$' % (b, n))

plt.xlim(-0.5, 200)
plt.ylim(0, 0.3)

plt.xticks(np.arange(0, 201, step=20))
plt.xlabel('$x$')
plt.ylabel(r'$p(x|b, n)$')
plt.title('Binomial Distribution')

plt.legend()
plt.show()
fig.savefig('Binomial.png')

# %%
def checkinput(q_est):
    q_new = [-0.001]
    q_new.extend([q_est[i] for i in range(len(q_est)-1)])
    for i in range(len(q_est)):
        if q_new[i] >= q_est[i]:
#             print ("crossing at", i)
            return False
    return True

# SGD which works for q_est non positive, only constant stepsize
def sgd(q_est, x, tau, stepsize):
    if x > q_est:
        q_est += stepsize*tau
    else:
        q_est += stepsize*(tau-1)
    return q_est

def SGD(dataset, tau_lst, stepsize, q):
    count = 0
    proc = np.zeros((len(dataset), len(tau_lst)))
    for i, x in enumerate(dataset):
        for k in range(len(tau_lst)):
            tau = tau_lst[k]
            q[k] = sgd(q[k], x, tau, stepsize)
        if not (checkinput(q)):
            count += 1
        proc[i] = q
    return count, proc

# %%
import matplotlib.colors as colors
import matplotlib.cm as cmx

c_Norm = colors.Normalize(vmin=0, vmax=1)
scalarMap = cmx.ScalarMappable(norm=c_Norm, cmap=plt.get_cmap('gist_ncar'))
dataset = np.random.uniform(0,100, 5000)
q_true = np.asarray((tau_lst))*100

tau_lst = [0.15, 0.16, 0.17, 0.25, 0.5, 0.8, 0.9]

c1, proc1 = SGD(dataset, tau_lst, 5, np.asarray(tau_lst))
c2, proc2 = SGD(dataset, tau_lst, 1, np.asarray(tau_lst))
c3, proc3 = SGD(dataset, tau_lst, 0.45, np.asarray(tau_lst))


fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize = (17, 8), sharey=True)
            
for i, p in enumerate(proc1.T): 
    colorVal = scalarMap.to_rgba(tau_lst[i])
    ax1.plot(p, color=colorVal)
ax1.set_title("SGD (step size = 5)")


for i, p in enumerate(proc2.T):
    colorVal = scalarMap.to_rgba(tau_lst[i])                
    ax2.plot(p, color=colorVal)
ax2.set_title("SGD (step size = 1)")

for i, p in enumerate(proc3.T):
    colorVal = scalarMap.to_rgba(tau_lst[i])                
    ax3.plot(p, color=colorVal)
# ax2.plot(proc2)
ax3.set_title("SGD (step size = 0.45)")
# print (q_true)

for i, qt in enumerate(q_true):
    colorVal = scalarMap.to_rgba(tau_lst[i])               
    ax1.axhline(qt, linestyle='--', color = colorVal, label=(str(tau_lst[i])+'-q true'))
    ax2.axhline(qt, linestyle='--', color = colorVal, label=(str(tau_lst[i])+'-q true'))
    ax3.axhline(qt, linestyle='--', color = colorVal, label=(str(tau_lst[i])+'-q true'))

lgd = ax1.legend(bbox_to_anchor=(3.8, 0.65), ncol = 1)

fig.suptitle("Test on uniform distribution over $U$(0,100)", fontsize=16)
plt.show()
fig.savefig("SGD_vs_SGD.png", bbox_extra_artists=[lgd, fig], bbox_inches='tight')

print ("ShiftQ res", proc1[-1, :])
print ("SGD res   ", proc2[-1, :])
print ("True res  ", q_true)


# SGD overall crossings 2882
# SGD overall crossings 659
# SGD overall crossings 25
# Out:
# ShiftQ res [20.15 20.16 20.17 20.25 40.5  70.8  85.9 ]
# SGD res    [16.15 16.16 18.17 23.25 45.5  77.8  88.9 ]
# True res   [15. 16. 17. 25. 50. 80. 90.]

# %%
for step_size in [5, 1, 0.45]:
    counts = np.zeros(100)
    for i in range(100):
        dataset = np.random.uniform(0,100, 5000)
        counts[i], _ = SGD(dataset, tau_lst, step_size, np.asarray(tau_lst))
    print ("Step size", step_size, ", Mean crossing", counts.mean(), ", Std crossing", counts.std())
# Out:
# Step size 5 , Mean crossing 2830.56 , Std crossing 113.40972797780623
# Step size 1 , Mean crossing 664.17 , Std crossing 165.5919717256848
# Step size 0.45 , Mean crossing 104.43 , Std crossing 80.93259602904135
