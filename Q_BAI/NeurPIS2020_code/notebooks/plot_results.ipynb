# %%
# direct to proper path
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
import numpy as np
from ipywidgets import IntProgress
from IPython.display import display
import matplotlib.pyplot as plt
from collections import defaultdict
import seaborn as sns
import pickle
from prettytable import PrettyTable

from codes.Q_BAI import Q_SAR, uniform_sampling, Q_UGapEb, Q_SAR_Simplified
from codes.Mean_BAI import UGapEb, SAR_Simplified
from codes.Environment import Mixture_AbsGau, setup_env, Exp
from codes.SimulatedGames import simulate, simulate_mean
from codes.plots import plot_hist, plot_eva, plot_eva_m

# %matplotlib inline

# %%
with open('../Fixed_budget_20arms_new_env_group_one_est_gap_2500budget.pickle', 'rb') as handle:
     results = pickle.load(handle)
        
plot_eva(results, 'pe', paper_flag = True, with_para = True, title = 'Group_One_Fixed_Budget', log_scale = False)

# %%
with open('../Fixed_budget_20arms_new_env_group_two_est_gap.pickle', 'rb') as handle:
     results = pickle.load(handle)
        
plot_eva(results, 'pe', paper_flag = True, with_para = False, title = 'Group_Two_Fixed_Budget', log_scale = False, save_flag = True)

# %%
with open('../saved_results/Fixed_confi_20arms_new_env_group_one.pickle', 'rb') as handle:
     results = pickle.load(handle)
        
plot_eva(results, 'sc', paper_flag = True, with_para = True, title = 'Group_One_Fixed_Confidence', log_scale = True)

# %%
with open('../saved_results/Fixed_confi_20arms_new_env_group_two.pickle', 'rb') as handle:
     results = pickle.load(handle)
        
plot_eva(results, 'sc', paper_flag = False, with_para = True, title = 'Group_Two_Fixed_Confidence', log_scale = True)

# %%
#for key, value in results.items():
#    for key1, value1 in results[key].items():
#        if key1 == 'Q_UGapEc-[0.0001]':
