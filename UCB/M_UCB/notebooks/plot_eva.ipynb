# %%
# direct to proper path
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
from codes.plots import plot_hist, plot_eva, plot_eva_for_clinical, plot_eva_num_arms

# %matplotlib inline

# %%
import pickle

with open('results_more_arms.pickle', 'rb') as handle:
    results = pickle.load(handle)

# %%
plot_eva_num_arms(results, 'sd', mean_at = 9900, paper_flag = False)
