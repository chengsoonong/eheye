# %%
import pickle
import plots

# %% [markdown]
# ### Plot results
#
# plot results generated from ucb_order_statistics

# %%
with open('os_saving.pickle', 'rb') as handle:
    b = pickle.load(handle)

# %% [markdown]
# ### Comb
#
# For para [0.7, 0.7, 1]
# L [0.84, 1.4, 1]
# First arm is AbsGau, the other two are Exp
#
# True: set L = 0.8
# False: set L = 1.4

# %%
plots.plot_eva(b, 'sd', 'raw')

# %%
plots.plot_eva(b, 'bd', 'raw')

# %%
#plots.plot_log_curve_fit(b['AbsGau_10_1000']['True[0.2, 0.5]']['sd'], 'AbsGau_10_1000_True[0.2, 0.5]_sd')

# %% [markdown]
# ### Individual: AbsGau or Exp
#
# didn't tune parameter for UCB1 yet
#
# Some problems:
# For Exp, the gap between estimate and true vairance is large
# Bound is too big

# %%
with open('os_saving_with_ucb1.pickle', 'rb') as handle:
    a = pickle.load(handle)

# %%
plots.plot_eva(a, 'sd', 'raw')

# %%
plots.plot_eva(a, 'sd', 'raw') # with bound
